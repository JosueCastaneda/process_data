# %% [markdown]
# # Results for local code

# %% [markdown]
# ## 0. Load libraries

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import scipy.stats as st
import pickle
import seaborn as sns   

#%matplotlib inline

# %% [markdown]
# ## 1. Initialize variables

# %%
recalculate_if_saved = True
# repetitions = 26
repetitions = 1
number_of_updates = 150
algorithm_list = ['corrective', 'standard', 'preventive']
types_list = ['concurrent']
delay_list = ['1', '10', '100', '1000', '10000', '10000']
repetition_probability_list = ['0']
negation_probability_list = ['0', '5', '10', '20', '40', '80']
file_path = 'local/test/results_experiment_'
new_columns_metrics = ['inconsistencies', 
                       'messages_sent', 
                       'latency_per_operation', 
                       'overhead_data_structure', 
                       'overhead_per_message', 
                       'number_of_reconfigurations', 
                       'total_reconfiguration_time',
                       'result_algorithm',
                       'type',
                       'negation_probability',
                       'delay',
                       'repetition_probability',
                       'update']
file_path_images = '/images/seaborn/'
type_exp = 'concurrent'
current_directory = os.getcwd()
all_results = pd.DataFrame(columns=new_columns_metrics)

# %%
def save_all_dataframes_as_pickle(all_results):
    print('Saving....')
    current_directory = os.getcwd()
    path_results = '/saved_dataframes/'
    string_name = 'data_frame_'
    pickle.dump(all_results, open(current_directory + path_results + '/single_value/dataframe_data_all.p' , 'wb'))
    print('Saved!')

# %%
def recalculate_overhead_data_structure(data):
    result = data.copy()
    after_copy = data.copy()
    before_copy = data.copy()
    
    for i in range(1, len(result)):
        result.loc[i, 'overhead_data_structure'] = after_copy.loc[i,'overhead_data_structure'] - before_copy.loc[i - 1]['overhead_data_structure']
    return result

# %%
def calculate_values(all_results):    
    new_number = number_of_updates
    one_time_print = False
    for repetition_index in range(0, repetitions + 1):
        file_path = 'local/test/results_experiment_' + str(new_number)
        data = dict()
        data['update'] = number_of_updates * (repetition_index + 1)
        for delay in delay_list:
            data['delay'] = delay
            for repetition_probability in repetition_probability_list:
                data['repetition'] = repetition_probability
                for negation_probability in negation_probability_list:
                    data['negation'] = negation_probability
                    for algorithm in algorithm_list:
                        data['algorithm'] = algorithm
                        for alg_type in types_list:  
                            data['alg_type'] = alg_type
                            str_1 = 'result_algorithm_*' + algorithm + '*_type_*' + alg_type + '*_negationProbability_*' + str(negation_probability)
                            str_2 = '*_delay_*' + str(delay) + '.0*_repetitionProbability_*' + str(repetition_probability) + '*.csv'
                            file_name = str_1 + str_2
                            try:
                                result = pd.read_csv(file_path +'/' + file_name, encoding='utf-8', sep=r'\s*,\s*', header=0, engine='python')                                                                
                                result['result_algorithm'] = [algorithm]*len(result)
                                result['type'] = [alg_type]*len(result)
                                result['negation_probability'] = [str(negation_probability)]*len(result)
                                result['delay'] = [str(delay)]*len(result)
                                result['repetition_probability'] = [str(repetition_probability)]*len(result)
                                result['update'] = [str( data['update'])]*len(result)
                                display(result.head())
                                updated_result = recalculate_overhead_data_structure(result)
                                print('AFTER PROCESSING ALL RESULT VALUE')
                                display(updated_result.head())
#                                 for index, row in updated_result.iterrows():                                           
#                                     all_results = all_results.append(row, ignore_index=True)                                      
                            except FileNotFoundError as e:
                                print(e)

        new_number += number_of_updates
#     save_all_dataframes_as_pickle(all_results)
    return all_results

# %%
def load_values():
    print('Loading...')
    path_results = '/saved_dataframes/'
    current_directory = os.getcwd()
    loaded_data = pickle.load(open(current_directory + path_results + '/single_value/dataframe_data_all.p' , 'rb'))
    print('Loaded!')
    return loaded_data

# %%
if recalculate_if_saved:
    all_results = calculate_values(all_results)
# Out:
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0            296                  0.013
# 1                0            359                  0.027
# 2                0            334                  0.035
# 3                0            340                  0.047
# 4                0            333                  0.061
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  82760.0              251400.0                         0.0
# 1                 178248.0              307895.0                         0.0
# 2                 250664.0              284110.0                         0.0
# 3                 338296.0              290420.0                         0.0
# 4                 415736.0              284525.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.007       corrective  concurrent
# 1                       0.010       corrective  concurrent
# 2                       0.010       corrective  concurrent
# 3                       0.010       corrective  concurrent
# 4                       0.011       corrective  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    0     1                      0    150
# 1                    0     1                      0    150
# 2                    0     1                      0    150
# 3                    0     1                      0    150
# 4                    0     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0            296                  0.013
# 1                0            359                  0.027
# 2                0            334                  0.035
# 3                0            340                  0.047
# 4                0            333                  0.061
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  82760.0              251400.0                         0.0
# 1                  95488.0              307895.0                         0.0
# 2                  72416.0              284110.0                         0.0
# 3                  87632.0              290420.0                         0.0
# 4                  77440.0              284525.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.007       corrective  concurrent
# 1                       0.010       corrective  concurrent
# 2                       0.010       corrective  concurrent
# 3                       0.010       corrective  concurrent
# 4                       0.011       corrective  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    0     1                      0    150
# 1                    0     1                      0    150
# 2                    0     1                      0    150
# 3                    0     1                      0    150
# 4                    0     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0               60            296                  0.052
# 1               17            359                  0.065
# 2               24            334                  0.067
# 3               14            340                  0.073
# 4                9            333                  0.086
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12052.0              348096.0                         1.0
# 1                  26240.0              422184.0                         1.0
# 2                  37108.0              392784.0                         1.0
# 3                  50216.0              399840.0                         1.0
# 4                  61844.0              391608.0                         1.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.027         standard  concurrent
# 1                       0.033         standard  concurrent
# 2                       0.033         standard  concurrent
# 3                       0.036         standard  concurrent
# 4                       0.036         standard  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    0     1                      0    150
# 1                    0     1                      0    150
# 2                    0     1                      0    150
# 3                    0     1                      0    150
# 4                    0     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0               60            296                  0.052
# 1               17            359                  0.065
# 2               24            334                  0.067
# 3               14            340                  0.073
# 4                9            333                  0.086
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12052.0              348096.0                         1.0
# 1                  14188.0              422184.0                         1.0
# 2                  10868.0              392784.0                         1.0
# 3                  13108.0              399840.0                         1.0
# 4                  11628.0              391608.0                         1.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.027         standard  concurrent
# 1                       0.033         standard  concurrent
# 2                       0.033         standard  concurrent
# 3                       0.036         standard  concurrent
# 4                       0.036         standard  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    0     1                      0    150
# 1                    0     1                      0    150
# 2                    0     1                      0    150
# 3                    0     1                      0    150
# 4                    0     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1068                 43.924
# 1                0           1370                 66.112
# 2                0           1216                 56.809
# 3                0           1268                 52.066
# 4                0           1244                 54.296
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   4088.0             1633606.0                         0.0
# 1                   4680.0             2124669.0                         0.0
# 2                   4392.0             1857240.0                         0.0
# 3                   4520.0             1953256.0                         0.0
# 4                   4520.0             1918427.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.040       preventive  concurrent
# 1                       0.049       preventive  concurrent
# 2                       0.045       preventive  concurrent
# 3                       0.048       preventive  concurrent
# 4                       0.051       preventive  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    0     1                      0    150
# 1                    0     1                      0    150
# 2                    0     1                      0    150
# 3                    0     1                      0    150
# 4                    0     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1068                 43.924
# 1                0           1370                 66.112
# 2                0           1216                 56.809
# 3                0           1268                 52.066
# 4                0           1244                 54.296
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   4088.0             1633606.0                         0.0
# 1                    592.0             2124669.0                         0.0
# 2                   -288.0             1857240.0                         0.0
# 3                    128.0             1953256.0                         0.0
# 4                      0.0             1918427.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.040       preventive  concurrent
# 1                       0.049       preventive  concurrent
# 2                       0.045       preventive  concurrent
# 3                       0.048       preventive  concurrent
# 4                       0.051       preventive  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    0     1                      0    150
# 1                    0     1                      0    150
# 2                    0     1                      0    150
# 3                    0     1                      0    150
# 4                    0     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0            336                  0.015
# 1                0            410                  0.029
# 2                0            379                  0.037
# 3                0            390                  0.052
# 4                0            379                  0.058
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  83960.0              287120.0                        40.0
# 1                 178664.0              353234.0                        42.0
# 2                 251592.0              323875.0                        45.0
# 3                 338840.0              335430.0                        50.0
# 4                 415960.0              325099.0                        38.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.008       corrective  concurrent
# 1                       0.009       corrective  concurrent
# 2                       0.008       corrective  concurrent
# 3                       0.010       corrective  concurrent
# 4                       0.008       corrective  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    5     1                      0    150
# 1                    5     1                      0    150
# 2                    5     1                      0    150
# 3                    5     1                      0    150
# 4                    5     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0            336                  0.015
# 1                0            410                  0.029
# 2                0            379                  0.037
# 3                0            390                  0.052
# 4                0            379                  0.058
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  83960.0              287120.0                        40.0
# 1                  94704.0              353234.0                        42.0
# 2                  72928.0              323875.0                        45.0
# 3                  87248.0              335430.0                        50.0
# 4                  77120.0              325099.0                        38.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.008       corrective  concurrent
# 1                       0.009       corrective  concurrent
# 2                       0.008       corrective  concurrent
# 3                       0.010       corrective  concurrent
# 4                       0.008       corrective  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    5     1                      0    150
# 1                    5     1                      0    150
# 2                    5     1                      0    150
# 3                    5     1                      0    150
# 4                    5     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0               53            296                  0.057
# 1               28            359                  0.070
# 2               26            334                  0.073
# 3               17            340                  0.082
# 4                9            333                  0.089
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12052.0              348096.0                         1.0
# 1                  26240.0              422184.0                         1.0
# 2                  37108.0              392784.0                         1.0
# 3                  50216.0              399840.0                         1.0
# 4                  61844.0              391608.0                         1.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.031         standard  concurrent
# 1                       0.037         standard  concurrent
# 2                       0.035         standard  concurrent
# 3                       0.040         standard  concurrent
# 4                       0.040         standard  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    5     1                      0    150
# 1                    5     1                      0    150
# 2                    5     1                      0    150
# 3                    5     1                      0    150
# 4                    5     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0               53            296                  0.057
# 1               28            359                  0.070
# 2               26            334                  0.073
# 3               17            340                  0.082
# 4                9            333                  0.089
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12052.0              348096.0                         1.0
# 1                  14188.0              422184.0                         1.0
# 2                  10868.0              392784.0                         1.0
# 3                  13108.0              399840.0                         1.0
# 4                  11628.0              391608.0                         1.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.031         standard  concurrent
# 1                       0.037         standard  concurrent
# 2                       0.035         standard  concurrent
# 3                       0.040         standard  concurrent
# 4                       0.040         standard  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    5     1                      0    150
# 1                    5     1                      0    150
# 2                    5     1                      0    150
# 3                    5     1                      0    150
# 4                    5     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1068                 27.504
# 1                0           1370                 40.751
# 2                0           1216                 36.072
# 3                0           1268                 36.497
# 4                0           1244                 34.468
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   4088.0             1637638.0                         0.0
# 1                   4680.0             2129661.0                         0.0
# 2                   4392.0             1861848.0                         0.0
# 3                   4520.0             1957384.0                         0.0
# 4                   4520.0             1923035.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.020       preventive  concurrent
# 1                       0.028       preventive  concurrent
# 2                       0.029       preventive  concurrent
# 3                       0.035       preventive  concurrent
# 4                       0.027       preventive  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    5     1                      0    150
# 1                    5     1                      0    150
# 2                    5     1                      0    150
# 3                    5     1                      0    150
# 4                    5     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1068                 27.504
# 1                0           1370                 40.751
# 2                0           1216                 36.072
# 3                0           1268                 36.497
# 4                0           1244                 34.468
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   4088.0             1637638.0                         0.0
# 1                    592.0             2129661.0                         0.0
# 2                   -288.0             1861848.0                         0.0
# 3                    128.0             1957384.0                         0.0
# 4                      0.0             1923035.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.020       preventive  concurrent
# 1                       0.028       preventive  concurrent
# 2                       0.029       preventive  concurrent
# 3                       0.035       preventive  concurrent
# 4                       0.027       preventive  concurrent
#
#   negation_probability delay repetition_probability update
# 0                    5     1                      0    150
# 1                    5     1                      0    150
# 2                    5     1                      0    150
# 3                    5     1                      0    150
# 4                    5     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0            364                  0.018
# 1                0            444                  0.039
# 2                0            411                  0.040
# 3                0            425                  0.065
# 4                0            407                  0.073
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  84400.0              312092.0                        60.0
# 1                 179368.0              383140.0                        66.0
# 2                 251496.0              352243.0                        62.0
# 3                 338840.0              366705.0                        83.0
# 4                 415928.0              349671.0                        58.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.007       corrective  concurrent
# 1                       0.011       corrective  concurrent
# 2                       0.008       corrective  concurrent
# 3                       0.011       corrective  concurrent
# 4                       0.010       corrective  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   10     1                      0    150
# 1                   10     1                      0    150
# 2                   10     1                      0    150
# 3                   10     1                      0    150
# 4                   10     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0            364                  0.018
# 1                0            444                  0.039
# 2                0            411                  0.040
# 3                0            425                  0.065
# 4                0            407                  0.073
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  84400.0              312092.0                        60.0
# 1                  94968.0              383140.0                        66.0
# 2                  72128.0              352243.0                        62.0
# 3                  87344.0              366705.0                        83.0
# 4                  77088.0              349671.0                        58.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.007       corrective  concurrent
# 1                       0.011       corrective  concurrent
# 2                       0.008       corrective  concurrent
# 3                       0.011       corrective  concurrent
# 4                       0.010       corrective  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   10     1                      0    150
# 1                   10     1                      0    150
# 2                   10     1                      0    150
# 3                   10     1                      0    150
# 4                   10     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0               48            296                  0.055
# 1               22            359                  0.073
# 2               24            334                  0.065
# 3               21            340                  0.078
# 4               14            333                  0.084
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12052.0              348096.0                         1.0
# 1                  26240.0              422184.0                         1.0
# 2                  37108.0              392784.0                         1.0
# 3                  50216.0              399840.0                         1.0
# 4                  61844.0              391608.0                         1.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.029         standard  concurrent
# 1                       0.039         standard  concurrent
# 2                       0.031         standard  concurrent
# 3                       0.040         standard  concurrent
# 4                       0.036         standard  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   10     1                      0    150
# 1                   10     1                      0    150
# 2                   10     1                      0    150
# 3                   10     1                      0    150
# 4                   10     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0               48            296                  0.055
# 1               22            359                  0.073
# 2               24            334                  0.065
# 3               21            340                  0.078
# 4               14            333                  0.084
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12052.0              348096.0                         1.0
# 1                  14188.0              422184.0                         1.0
# 2                  10868.0              392784.0                         1.0
# 3                  13108.0              399840.0                         1.0
# 4                  11628.0              391608.0                         1.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.029         standard  concurrent
# 1                       0.039         standard  concurrent
# 2                       0.031         standard  concurrent
# 3                       0.040         standard  concurrent
# 4                       0.036         standard  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   10     1                      0    150
# 1                   10     1                      0    150
# 2                   10     1                      0    150
# 3                   10     1                      0    150
# 4                   10     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1068                 29.979
# 1                0           1370                 42.019
# 2                0           1216                 38.648
# 3                0           1268                 33.838
# 4                0           1244                 35.089
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   4088.0             1639942.0                         0.0
# 1                   4680.0             2133213.0                         0.0
# 2                   4392.0             1864440.0                         0.0
# 3                   4520.0             1961800.0                         0.0
# 4                   4520.0             1926203.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.023       preventive  concurrent
# 1                       0.033       preventive  concurrent
# 2                       0.031       preventive  concurrent
# 3                       0.029       preventive  concurrent
# 4                       0.030       preventive  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   10     1                      0    150
# 1                   10     1                      0    150
# 2                   10     1                      0    150
# 3                   10     1                      0    150
# 4                   10     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1068                 29.979
# 1                0           1370                 42.019
# 2                0           1216                 38.648
# 3                0           1268                 33.838
# 4                0           1244                 35.089
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   4088.0             1639942.0                         0.0
# 1                    592.0             2133213.0                         0.0
# 2                   -288.0             1864440.0                         0.0
# 3                    128.0             1961800.0                         0.0
# 4                      0.0             1926203.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.023       preventive  concurrent
# 1                       0.033       preventive  concurrent
# 2                       0.031       preventive  concurrent
# 3                       0.029       preventive  concurrent
# 4                       0.030       preventive  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   10     1                      0    150
# 1                   10     1                      0    150
# 2                   10     1                      0    150
# 3                   10     1                      0    150
# 4                   10     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0            421                  0.020
# 1                0            522                  0.038
# 2                0            477                  0.046
# 3                0            485                  0.063
# 4                0            460                  0.077
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  84368.0              363005.0                       102.0
# 1                 179144.0              453682.0                       135.0
# 2                 252008.0              411157.0                       121.0
# 3                 339128.0              419725.0                       114.0
# 4                 416664.0              396388.0                       115.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.007       corrective  concurrent
# 1                       0.009       corrective  concurrent
# 2                       0.008       corrective  concurrent
# 3                       0.009       corrective  concurrent
# 4                       0.010       corrective  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   20     1                      0    150
# 1                   20     1                      0    150
# 2                   20     1                      0    150
# 3                   20     1                      0    150
# 4                   20     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0            421                  0.020
# 1                0            522                  0.038
# 2                0            477                  0.046
# 3                0            485                  0.063
# 4                0            460                  0.077
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  84368.0              363005.0                       102.0
# 1                  94776.0              453682.0                       135.0
# 2                  72864.0              411157.0                       121.0
# 3                  87120.0              419725.0                       114.0
# 4                  77536.0              396388.0                       115.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.007       corrective  concurrent
# 1                       0.009       corrective  concurrent
# 2                       0.008       corrective  concurrent
# 3                       0.009       corrective  concurrent
# 4                       0.010       corrective  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   20     1                      0    150
# 1                   20     1                      0    150
# 2                   20     1                      0    150
# 3                   20     1                      0    150
# 4                   20     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0               55            296                  0.049
# 1               31            359                  0.065
# 2               32            334                  0.062
# 3               17            340                  0.075
# 4                9            333                  0.068
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12052.0              348096.0                         1.0
# 1                  26240.0              422184.0                         1.0
# 2                  37108.0              392784.0                         1.0
# 3                  50216.0              399840.0                         1.0
# 4                  61844.0              391608.0                         1.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.027         standard  concurrent
# 1                       0.034         standard  concurrent
# 2                       0.031         standard  concurrent
# 3                       0.041         standard  concurrent
# 4                       0.030         standard  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   20     1                      0    150
# 1                   20     1                      0    150
# 2                   20     1                      0    150
# 3                   20     1                      0    150
# 4                   20     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0               55            296                  0.049
# 1               31            359                  0.065
# 2               32            334                  0.062
# 3               17            340                  0.075
# 4                9            333                  0.068
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12052.0              348096.0                         1.0
# 1                  14188.0              422184.0                         1.0
# 2                  10868.0              392784.0                         1.0
# 3                  13108.0              399840.0                         1.0
# 4                  11628.0              391608.0                         1.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.027         standard  concurrent
# 1                       0.034         standard  concurrent
# 2                       0.031         standard  concurrent
# 3                       0.041         standard  concurrent
# 4                       0.030         standard  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   20     1                      0    150
# 1                   20     1                      0    150
# 2                   20     1                      0    150
# 3                   20     1                      0    150
# 4                   20     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1068                 20.751
# 1                0           1370                 28.146
# 2                0           1216                 26.041
# 3                0           1268                 26.389
# 4                0           1244                 26.806
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   4088.0             1646374.0                         0.0
# 1                   4680.0             2140221.0                         0.0
# 2                   4392.0             1870584.0                         0.0
# 3                   4520.0             1967944.0                         0.0
# 4                   4520.0             1930139.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.019       preventive  concurrent
# 1                       0.020       preventive  concurrent
# 2                       0.023       preventive  concurrent
# 3                       0.022       preventive  concurrent
# 4                       0.025       preventive  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   20     1                      0    150
# 1                   20     1                      0    150
# 2                   20     1                      0    150
# 3                   20     1                      0    150
# 4                   20     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1068                 20.751
# 1                0           1370                 28.146
# 2                0           1216                 26.041
# 3                0           1268                 26.389
# 4                0           1244                 26.806
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   4088.0             1646374.0                         0.0
# 1                    592.0             2140221.0                         0.0
# 2                   -288.0             1870584.0                         0.0
# 3                    128.0             1967944.0                         0.0
# 4                      0.0             1930139.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.019       preventive  concurrent
# 1                       0.020       preventive  concurrent
# 2                       0.023       preventive  concurrent
# 3                       0.022       preventive  concurrent
# 4                       0.025       preventive  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   20     1                      0    150
# 1                   20     1                      0    150
# 2                   20     1                      0    150
# 3                   20     1                      0    150
# 4                   20     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0            549                  0.030
# 1                0            714                  0.065
# 2                0            625                  0.088
# 3                0            679                  0.104
# 4                0            640                  0.130
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  85112.0              476397.0                       172.0
# 1                 179560.0              624290.0                       220.0
# 2                 251496.0              541849.0                       203.0
# 3                 338712.0              592911.0                       205.0
# 4                 416504.0              558168.0                       192.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.008       corrective  concurrent
# 1                       0.010       corrective  concurrent
# 2                       0.011       corrective  concurrent
# 3                       0.010       corrective  concurrent
# 4                       0.012       corrective  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   40     1                      0    150
# 1                   40     1                      0    150
# 2                   40     1                      0    150
# 3                   40     1                      0    150
# 4                   40     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0            549                  0.030
# 1                0            714                  0.065
# 2                0            625                  0.088
# 3                0            679                  0.104
# 4                0            640                  0.130
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  85112.0              476397.0                       172.0
# 1                  94448.0              624290.0                       220.0
# 2                  71936.0              541849.0                       203.0
# 3                  87216.0              592911.0                       205.0
# 4                  77792.0              558168.0                       192.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.008       corrective  concurrent
# 1                       0.010       corrective  concurrent
# 2                       0.011       corrective  concurrent
# 3                       0.010       corrective  concurrent
# 4                       0.012       corrective  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   40     1                      0    150
# 1                   40     1                      0    150
# 2                   40     1                      0    150
# 3                   40     1                      0    150
# 4                   40     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0               58            296                  0.051
# 1               35            359                  0.062
# 2               21            334                  0.057
# 3               17            340                  0.074
# 4               10            333                  0.066
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12052.0              348096.0                         1.0
# 1                  26240.0              422184.0                         1.0
# 2                  37108.0              392784.0                         1.0
# 3                  50216.0              399840.0                         1.0
# 4                  61844.0              391608.0                         1.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.028         standard  concurrent
# 1                       0.032         standard  concurrent
# 2                       0.029         standard  concurrent
# 3                       0.038         standard  concurrent
# 4                       0.030         standard  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   40     1                      0    150
# 1                   40     1                      0    150
# 2                   40     1                      0    150
# 3                   40     1                      0    150
# 4                   40     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0               58            296                  0.051
# 1               35            359                  0.062
# 2               21            334                  0.057
# 3               17            340                  0.074
# 4               10            333                  0.066
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12052.0              348096.0                         1.0
# 1                  14188.0              422184.0                         1.0
# 2                  10868.0              392784.0                         1.0
# 3                  13108.0              399840.0                         1.0
# 4                  11628.0              391608.0                         1.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.028         standard  concurrent
# 1                       0.032         standard  concurrent
# 2                       0.029         standard  concurrent
# 3                       0.038         standard  concurrent
# 4                       0.030         standard  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   40     1                      0    150
# 1                   40     1                      0    150
# 2                   40     1                      0    150
# 3                   40     1                      0    150
# 4                   40     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1068                 19.351
# 1                0           1370                 16.974
# 2                0           1216                 19.063
# 3                0           1268                 17.206
# 4                0           1244                 11.710
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   4088.0             1659142.0                         0.0
# 1                   4680.0             2159517.0                         0.0
# 2                   4392.0             1885560.0                         0.0
# 3                   4520.0             1987048.0                         0.0
# 4                   4520.0             1948283.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.014       preventive  concurrent
# 1                       0.012       preventive  concurrent
# 2                       0.016       preventive  concurrent
# 3                       0.014       preventive  concurrent
# 4                       0.013       preventive  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   40     1                      0    150
# 1                   40     1                      0    150
# 2                   40     1                      0    150
# 3                   40     1                      0    150
# 4                   40     1                      0    150
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1068                 19.351
# 1                0           1370                 16.974
# 2                0           1216                 19.063
# 3                0           1268                 17.206
# 4                0           1244                 11.710
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   4088.0             1659142.0                         0.0
# 1                    592.0             2159517.0                         0.0
# 2                   -288.0             1885560.0                         0.0
# 3                    128.0             1987048.0                         0.0
# 4                      0.0             1948283.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.014       preventive  concurrent
# 1                       0.012       preventive  concurrent
# 2                       0.016       preventive  concurrent
# 3                       0.014       preventive  concurrent
# 4                       0.013       preventive  concurrent
#
#   negation_probability delay repetition_probability update
# 0                   40     1                      0    150
# 1                   40     1                      0    150
# 2                   40     1                      0    150
# 3                   40     1                      0    150
# 4                   40     1                      0    150
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0            897                  0.038
# ...
# 0              261            611                  0.548
# 1              217            698                  0.634
# 2              143            676                  0.619
# 3               79            679                  0.651
# 4               97            671                  0.706
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12528.0              718536.0                         2.0
# 1                  26948.0              820848.0                         1.0
# 2                  38160.0              794976.0                         1.0
# 3                  51592.0              798504.0                         1.0
# 4                  63284.0              789096.0                         2.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.288         standard  concurrent
# 1                       0.315         standard  concurrent
# 2                       0.287         standard  concurrent
# 3                       0.311         standard  concurrent
# 4                       0.295         standard  concurrent
#
#   negation_probability  delay repetition_probability update
# 0                   40  10000                      0    300
# 1                   40  10000                      0    300
# 2                   40  10000                      0    300
# 3                   40  10000                      0    300
# 4                   40  10000                      0    300
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0              261            611                  0.548
# 1              217            698                  0.634
# 2              143            676                  0.619
# 3               79            679                  0.651
# 4               97            671                  0.706
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12528.0              718536.0                         2.0
# 1                  14420.0              820848.0                         1.0
# 2                  11212.0              794976.0                         1.0
# 3                  13432.0              798504.0                         1.0
# 4                  11692.0              789096.0                         2.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.288         standard  concurrent
# 1                       0.315         standard  concurrent
# 2                       0.287         standard  concurrent
# 3                       0.311         standard  concurrent
# 4                       0.295         standard  concurrent
#
#   negation_probability  delay repetition_probability update
# 0                   40  10000                      0    300
# 1                   40  10000                      0    300
# 2                   40  10000                      0    300
# 3                   40  10000                      0    300
# 4                   40  10000                      0    300
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           2216                  6.586
# 1                0           2600                  7.922
# 2                0           2496                  8.073
# 3                0           2496                  8.559
# 4                0           2498                  5.663
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   8160.0             3456745.0                         0.0
# 1                   8576.0             4069650.0                         0.0
# 2                   8608.0             3893312.0                         0.0
# 3                   8832.0             3889685.0                         0.0
# 4                   8576.0             3911999.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.077       preventive  concurrent
# 1                       0.083       preventive  concurrent
# 2                       0.090       preventive  concurrent
# 3                       0.100       preventive  concurrent
# 4                       0.065       preventive  concurrent
#
#   negation_probability  delay repetition_probability update
# 0                   40  10000                      0    300
# 1                   40  10000                      0    300
# 2                   40  10000                      0    300
# 3                   40  10000                      0    300
# 4                   40  10000                      0    300
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           2216                  6.586
# 1                0           2600                  7.922
# 2                0           2496                  8.073
# 3                0           2496                  8.559
# 4                0           2498                  5.663
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   8160.0             3456745.0                         0.0
# 1                    416.0             4069650.0                         0.0
# 2                     32.0             3893312.0                         0.0
# 3                    224.0             3889685.0                         0.0
# 4                   -256.0             3911999.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.077       preventive  concurrent
# 1                       0.083       preventive  concurrent
# 2                       0.090       preventive  concurrent
# 3                       0.100       preventive  concurrent
# 4                       0.065       preventive  concurrent
#
#   negation_probability  delay repetition_probability update
# 0                   40  10000                      0    300
# 1                   40  10000                      0    300
# 2                   40  10000                      0    300
# 3                   40  10000                      0    300
# 4                   40  10000                      0    300
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1832                  0.263
# 1                0           2149                  0.609
# 2                0           2057                  0.743
# 3                0           2053                  0.796
# 4                0           2066                  1.187
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  89464.0             1603584.0                       375.0
# 1                 185816.0             1884829.0                       416.0
# 2                 260648.0             1802129.0                       398.0
# 3                 350984.0             1796421.0                       398.0
# 4                 428752.0             1813850.0                       409.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.042       corrective  concurrent
# 1                       0.048       corrective  concurrent
# 2                       0.048       corrective  concurrent
# 3                       0.043       corrective  concurrent
# 4                       0.050       corrective  concurrent
#
#   negation_probability  delay repetition_probability update
# 0                   80  10000                      0    300
# 1                   80  10000                      0    300
# 2                   80  10000                      0    300
# 3                   80  10000                      0    300
# 4                   80  10000                      0    300
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           1832                  0.263
# 1                0           2149                  0.609
# 2                0           2057                  0.743
# 3                0           2053                  0.796
# 4                0           2066                  1.187
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  89464.0             1603584.0                       375.0
# 1                  96352.0             1884829.0                       416.0
# 2                  74832.0             1802129.0                       398.0
# 3                  90336.0             1796421.0                       398.0
# 4                  77768.0             1813850.0                       409.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.042       corrective  concurrent
# 1                       0.048       corrective  concurrent
# 2                       0.048       corrective  concurrent
# 3                       0.043       corrective  concurrent
# 4                       0.050       corrective  concurrent
#
#   negation_probability  delay repetition_probability update
# 0                   80  10000                      0    300
# 1                   80  10000                      0    300
# 2                   80  10000                      0    300
# 3                   80  10000                      0    300
# 4                   80  10000                      0    300
#    inconsistencies  messages_sent  latency_per_operation  \
# 0              235            611                  0.487
# 1              213            698                  0.567
# 2              141            676                  0.582
# 3               87            679                  0.656
# 4               88            671                  0.552
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12528.0              718536.0                         0.0
# 1                  26948.0              820848.0                         2.0
# 2                  38160.0              794976.0                         1.0
# 3                  51592.0              798504.0                         1.0
# 4                  63284.0              789096.0                         2.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.246         standard  concurrent
# 1                       0.273         standard  concurrent
# 2                       0.266         standard  concurrent
# 3                       0.324         standard  concurrent
# 4                       0.229         standard  concurrent
#
#   negation_probability  delay repetition_probability update
# 0                   80  10000                      0    300
# 1                   80  10000                      0    300
# 2                   80  10000                      0    300
# 3                   80  10000                      0    300
# 4                   80  10000                      0    300
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0              235            611                  0.487
# 1              213            698                  0.567
# 2              141            676                  0.582
# 3               87            679                  0.656
# 4               88            671                  0.552
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                  12528.0              718536.0                         0.0
# 1                  14420.0              820848.0                         2.0
# 2                  11212.0              794976.0                         1.0
# 3                  13432.0              798504.0                         1.0
# 4                  11692.0              789096.0                         2.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.246         standard  concurrent
# 1                       0.273         standard  concurrent
# 2                       0.266         standard  concurrent
# 3                       0.324         standard  concurrent
# 4                       0.229         standard  concurrent
#
#   negation_probability  delay repetition_probability update
# 0                   80  10000                      0    300
# 1                   80  10000                      0    300
# 2                   80  10000                      0    300
# 3                   80  10000                      0    300
# 4                   80  10000                      0    300
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           2216                  0.763
# 1                0           2600                  0.475
# 2                0           2496                  0.577
# 3                0           2496                  0.822
# 4                0           2498                  0.414
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   8160.0             3515181.0                         0.0
# 1                   8576.0             4138390.0                         0.0
# 2                   8608.0             3959450.0                         0.0
# 3                   8832.0             3955049.0                         0.0
# 4                   8576.0             3977361.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.009       preventive  concurrent
# 1                       0.007       preventive  concurrent
# 2                       0.007       preventive  concurrent
# 3                       0.008       preventive  concurrent
# 4                       0.005       preventive  concurrent
#
#   negation_probability  delay repetition_probability update
# 0                   80  10000                      0    300
# 1                   80  10000                      0    300
# 2                   80  10000                      0    300
# 3                   80  10000                      0    300
# 4                   80  10000                      0    300
# AFTER PROCESSING ALL RESULT VALUE
#    inconsistencies  messages_sent  latency_per_operation  \
# 0                0           2216                  0.763
# 1                0           2600                  0.475
# 2                0           2496                  0.577
# 3                0           2496                  0.822
# 4                0           2498                  0.414
#
#    overhead_data_structure  overhead_per_message  number_of_reconfigurations  \
# 0                   8160.0             3515181.0                         0.0
# 1                    416.0             4138390.0                         0.0
# 2                     32.0             3959450.0                         0.0
# 3                    224.0             3955049.0                         0.0
# 4                   -256.0             3977361.0                         0.0
#
#    total_reconfiguration_time result_algorithm        type  \
# 0                       0.009       preventive  concurrent
# 1                       0.007       preventive  concurrent
# 2                       0.007       preventive  concurrent
# 3                       0.008       preventive  concurrent
# 4                       0.005       preventive  concurrent
#
#   negation_probability  delay repetition_probability update
# 0                   80  10000                      0    300
# 1                   80  10000                      0    300
# 2                   80  10000                      0    300
# 3                   80  10000                      0    300
# 4                   80  10000                      0    300
