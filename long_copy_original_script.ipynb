# %% [markdown]
# # Results for local code

# %% [markdown]
# # 0. Load libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pylab as pl
import math
import os
import pickle
#%matplotlib inline

# %% [markdown]
# # Create variables to store

# %%
recalculate_if_saved = True
repetitions = 8
number_of_updates = 150
algorithm_list = ['causal', 'corrective', 'standard', 'preventive']
types_list = ['concurrent', 'sequential']
delay_list = ['1', '100', '1000']
repetition_probability_list = ['0', '5', '10']
negation_probability_list = ['0', '5', '10']

index_list = []
for i in range(150, 3150, 150):
    index_list.append(i)


file_path = 'local/test/results_experiment_'
columns_metrics = ['inconsistencies', 'messages_sent', 'latency_per_operation', 'overhead_data_structure', 'overhead_per_message', 'number_of_reconfigurations', 'total_reconfiguration_time']

# %%
# Preventive

## Concurrent

### Delay 1

data_frame_preventive_concurrent_delay_1_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_concurrent_delay_1_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_concurrent_delay_1_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 100

data_frame_preventive_concurrent_delay_100_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_100_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_100_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_concurrent_delay_100_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_100_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_100_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_concurrent_delay_100_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_100_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_100_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 1000

data_frame_preventive_concurrent_delay_1000_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1000_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1000_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_concurrent_delay_1000_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1000_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1000_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_concurrent_delay_1000_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1000_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_concurrent_delay_1000_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

## Sequential

### Delay 1
data_frame_preventive_sequential_delay_1_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_sequential_delay_1_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_sequential_delay_1_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)


### Delay 100

data_frame_preventive_sequential_delay_100_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_100_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_100_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_sequential_delay_100_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_100_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_100_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_sequential_delay_100_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_100_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_100_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 1000

data_frame_preventive_sequential_delay_1000_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1000_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1000_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_sequential_delay_1000_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1000_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1000_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_preventive_sequential_delay_1000_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1000_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_preventive_sequential_delay_1000_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

# %%
# Corrective

## Concurrent

### Delay 1

data_frame_corrective_concurrent_delay_1_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_concurrent_delay_1_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_concurrent_delay_1_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 100

data_frame_corrective_concurrent_delay_100_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_100_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_100_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_concurrent_delay_100_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_100_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_100_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_concurrent_delay_100_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_100_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_100_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 1000

data_frame_corrective_concurrent_delay_1000_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1000_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1000_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_concurrent_delay_1000_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1000_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1000_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_concurrent_delay_1000_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1000_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_concurrent_delay_1000_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

## Sequential

### Delay 1
data_frame_corrective_sequential_delay_1_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_sequential_delay_1_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_sequential_delay_1_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)


### Delay 100

data_frame_corrective_sequential_delay_100_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_100_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_100_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_sequential_delay_100_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_100_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_100_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_sequential_delay_100_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_100_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_100_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 1000

data_frame_corrective_sequential_delay_1000_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1000_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1000_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_sequential_delay_1000_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1000_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1000_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_corrective_sequential_delay_1000_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1000_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_corrective_sequential_delay_1000_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

# %%
# Standard

## Concurrent

### Delay 1

data_frame_standard_concurrent_delay_1_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_concurrent_delay_1_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_concurrent_delay_1_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 100

data_frame_standard_concurrent_delay_100_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_100_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_100_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_concurrent_delay_100_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_100_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_100_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_concurrent_delay_100_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_100_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_100_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 1000

data_frame_standard_concurrent_delay_1000_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1000_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1000_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_concurrent_delay_1000_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1000_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1000_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_concurrent_delay_1000_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1000_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_concurrent_delay_1000_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

## Sequential

### Delay 1
data_frame_standard_sequential_delay_1_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_sequential_delay_1_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_sequential_delay_1_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)


### Delay 100

data_frame_standard_sequential_delay_100_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_100_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_100_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_sequential_delay_100_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_100_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_100_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_sequential_delay_100_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_100_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_100_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 1000

data_frame_standard_sequential_delay_1000_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1000_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1000_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_sequential_delay_1000_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1000_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1000_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_standard_sequential_delay_1000_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1000_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_standard_sequential_delay_1000_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

# %%
# Causal 

## Concurrent

### Delay 1

data_frame_causal_concurrent_delay_1_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_concurrent_delay_1_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_concurrent_delay_1_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 100

data_frame_causal_concurrent_delay_100_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_100_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_100_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_concurrent_delay_100_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_100_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_100_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_concurrent_delay_100_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_100_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_100_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 1000

data_frame_causal_concurrent_delay_1000_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1000_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1000_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_concurrent_delay_1000_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1000_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1000_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_concurrent_delay_1000_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1000_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_concurrent_delay_1000_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

## Sequential

### Delay 1
data_frame_causal_sequential_delay_1_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_sequential_delay_1_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_sequential_delay_1_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)


### Delay 100

data_frame_causal_sequential_delay_100_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_100_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_100_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_sequential_delay_100_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_100_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_100_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_sequential_delay_100_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_100_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_100_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

### Delay 1000

data_frame_causal_sequential_delay_1000_repetition_0_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1000_repetition_0_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1000_repetition_0_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_sequential_delay_1000_repetition_5_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1000_repetition_5_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1000_repetition_5_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

data_frame_causal_sequential_delay_1000_repetition_10_negation_0 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1000_repetition_10_negation_5 = pd.DataFrame(columns=columns_metrics, index=index_list)
data_frame_causal_sequential_delay_1000_repetition_10_negation_10 = pd.DataFrame(columns=columns_metrics, index=index_list)

# %%
def add_results_to_corrective_concurrent(value, data):
    var_name = 'data_frame_corrective_concurrent' + '_delay_' + data['delay'] + '_repetition_' + data['repetition'] + '_negation_' + data['negation']
    var = globals()[var_name]
    var.loc[data['update']] = value
    
    
#     if data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '0':
#         data_frame_corrective_concurrent_delay_1_repetition_0_negation_0.loc[data['update']] = value
        
#     elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '5':
#         data_frame_corrective_concurrent_delay_1_repetition_0_negation_5.loc[data['update']] = value
    
#     elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '10':
#         data_frame_corrective_concurrent_delay_1_repetition_0_negation_10.loc[data['update']] = value
    
#     elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '0':
#         data_frame_corrective_concurrent_delay_1_repetition_5_negation_0.loc[data['update']] = value
        
#     elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '5':
#         data_frame_corrective_concurrent_delay_1_repetition_5_negation_5.loc[data['update']] = value
    
#     elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '10':
#         data_frame_corrective_concurrent_delay_1_repetition_5_negation_10.loc[data['update']] = value
        
#     elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '0':
#         data_frame_corrective_concurrent_delay_1_repetition_10_negation_0.loc[data['update']] = value
        
#     elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '5':
#         data_frame_corrective_concurrent_delay_1_repetition_10_negation_5.loc[data['update']] = value
    
#     elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '10':
#         data_frame_corrective_concurrent_delay_1_repetition_10_negation_10.loc[data['update']] = value
    
#     elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '0':
#         data_frame_corrective_concurrent_delay_100_repetition_0_negation_0.loc[data['update']] = value
        
#     elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '5':
#         data_frame_corrective_concurrent_delay_100_repetition_0_negation_5.loc[data['update']] = value
    
#     elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '10':
#         data_frame_corrective_concurrent_delay_100_repetition_0_negation_10.loc[data['update']] = value
    
#     elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '0':
#         data_frame_corrective_concurrent_delay_100_repetition_5_negation_0.loc[data['update']] = value
        
#     elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '5':
#         data_frame_corrective_concurrent_delay_100_repetition_5_negation_5.loc[data['update']] = value
    
#     elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '10':
#         data_frame_corrective_concurrent_delay_100_repetition_5_negation_10.loc[data['update']] = value
    
#     elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '0':
#         data_frame_corrective_concurrent_delay_100_repetition_10_negation_0.loc[data['update']] = value
        
#     elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '5':
#         data_frame_corrective_concurrent_delay_100_repetition_10_negation_5.loc[data['update']] = value
    
#     elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '10':
#         data_frame_corrective_concurrent_delay_100_repetition_10_negation_10.loc[data['update']] = value
    
#     elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '0':
#         data_frame_corrective_concurrent_delay_1000_repetition_0_negation_0.loc[data['update']] = value
        
#     elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '5':
#         data_frame_corrective_concurrent_delay_1000_repetition_0_negation_5.loc[data['update']] = value
    
#     elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '10':
#         data_frame_corrective_concurrent_delay_1000_repetition_0_negation_10.loc[data['update']] = value
    
#     elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '0':
#         data_frame_corrective_concurrent_delay_1000_repetition_5_negation_0.loc[data['update']] = value
        
#     elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '5':
#         data_frame_corrective_concurrent_delay_1000_repetition_5_negation_5.loc[data['update']] = value
    
#     elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '10':
#         data_frame_corrective_concurrent_delay_1000_repetition_5_negation_10.loc[data['update']] = value
    
#     elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '0':
#         data_frame_corrective_concurrent_delay_1000_repetition_10_negation_0.loc[data['update']] = value
        
#     elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '5':
#         data_frame_corrective_concurrent_delay_1000_repetition_10_negation_5.loc[data['update']] = value
    
#     elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '10':
#         data_frame_corrective_concurrent_delay_1000_repetition_10_negation_10.loc[data['update']] = value

# %%
def add_results_to_corrective_sequential(value, data):
    if data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_corrective_sequential_delay_1_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_corrective_sequential_delay_1_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_corrective_sequential_delay_1_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_corrective_sequential_delay_1_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_corrective_sequential_delay_1_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_corrective_sequential_delay_1_repetition_5_negation_10.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_corrective_sequential_delay_1_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_corrective_sequential_delay_1_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_corrective_sequential_delay_1_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_corrective_sequential_delay_100_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_corrective_sequential_delay_100_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_corrective_sequential_delay_100_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_corrective_sequential_delay_100_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_corrective_sequential_delay_100_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_corrective_sequential_delay_100_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_corrective_sequential_delay_100_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_corrective_sequential_delay_100_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_corrective_sequential_delay_100_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_corrective_sequential_delay_1000_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_corrective_sequential_delay_1000_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_corrective_sequential_delay_1000_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_corrective_sequential_delay_1000_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_corrective_sequential_delay_1000_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_corrective_sequential_delay_1000_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_corrective_sequential_delay_1000_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_corrective_sequential_delay_1000_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_corrective_sequential_delay_1000_repetition_10_negation_10.loc[data['update']] = value

# %%
def add_results_to_preventive_concurrent(value, data):
    if data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_preventive_concurrent_delay_1_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_preventive_concurrent_delay_1_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_preventive_concurrent_delay_1_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_preventive_concurrent_delay_1_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_preventive_concurrent_delay_1_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_preventive_concurrent_delay_1_repetition_5_negation_10.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_preventive_concurrent_delay_1_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_preventive_concurrent_delay_1_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_preventive_concurrent_delay_1_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_preventive_concurrent_delay_100_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_preventive_concurrent_delay_100_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_preventive_concurrent_delay_100_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_preventive_concurrent_delay_100_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_preventive_concurrent_delay_100_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_preventive_concurrent_delay_100_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_preventive_concurrent_delay_100_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_preventive_concurrent_delay_100_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_preventive_concurrent_delay_100_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_preventive_concurrent_delay_1000_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_preventive_concurrent_delay_1000_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_preventive_concurrent_delay_1000_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_preventive_concurrent_delay_1000_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_preventive_concurrent_delay_1000_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_preventive_concurrent_delay_1000_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_preventive_concurrent_delay_1000_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_preventive_concurrent_delay_1000_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_preventive_concurrent_delay_1000_repetition_10_negation_10.loc[data['update']] = value

# %%
def add_results_to_preventive_sequential(value, data):
    if data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_preventive_sequential_delay_1_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_preventive_sequential_delay_1_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_preventive_sequential_delay_1_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_preventive_sequential_delay_1_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_preventive_sequential_delay_1_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_preventive_sequential_delay_1_repetition_5_negation_10.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_preventive_sequential_delay_1_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_preventive_sequential_delay_1_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_preventive_sequential_delay_1_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_preventive_sequential_delay_100_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_preventive_sequential_delay_100_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_preventive_sequential_delay_100_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_preventive_sequential_delay_100_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_preventive_sequential_delay_100_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_preventive_sequential_delay_100_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_preventive_sequential_delay_100_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_preventive_sequential_delay_100_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_preventive_sequential_delay_100_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_preventive_sequential_delay_1000_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_preventive_sequential_delay_1000_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_preventive_sequential_delay_1000_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_preventive_sequential_delay_1000_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_preventive_sequential_delay_1000_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_preventive_sequential_delay_1000_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_preventive_sequential_delay_1000_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_preventive_sequential_delay_1000_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_preventive_sequential_delay_1000_repetition_10_negation_10.loc[data['update']] = value

# %%
def add_results_to_standard_concurrent(value, data):
    if data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_standard_concurrent_delay_1_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_standard_concurrent_delay_1_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_standard_concurrent_delay_1_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_standard_concurrent_delay_1_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_standard_concurrent_delay_1_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_standard_concurrent_delay_1_repetition_5_negation_10.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_standard_concurrent_delay_1_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_standard_concurrent_delay_1_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_standard_concurrent_delay_1_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_standard_concurrent_delay_100_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_standard_concurrent_delay_100_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_standard_concurrent_delay_100_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_standard_concurrent_delay_100_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_standard_concurrent_delay_100_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_standard_concurrent_delay_100_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_standard_concurrent_delay_100_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_standard_concurrent_delay_100_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_standard_concurrent_delay_100_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_standard_concurrent_delay_1000_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_standard_concurrent_delay_1000_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_standard_concurrent_delay_1000_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_standard_concurrent_delay_1000_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_standard_concurrent_delay_1000_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_standard_concurrent_delay_1000_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_standard_concurrent_delay_1000_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_standard_concurrent_delay_1000_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_standard_concurrent_delay_1000_repetition_10_negation_10.loc[data['update']] = value

# %%
def add_results_to_standard_sequential(value, data):
    if data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_standard_sequential_delay_1_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_standard_sequential_delay_1_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_standard_sequential_delay_1_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_standard_sequential_delay_1_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_standard_sequential_delay_1_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_standard_sequential_delay_1_repetition_5_negation_10.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_standard_sequential_delay_1_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_standard_sequential_delay_1_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_standard_sequential_delay_1_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_standard_sequential_delay_100_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_standard_sequential_delay_100_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_standard_sequential_delay_100_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_standard_sequential_delay_100_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_standard_sequential_delay_100_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_standard_sequential_delay_100_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_standard_sequential_delay_100_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_standard_sequential_delay_100_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_standard_sequential_delay_100_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_standard_sequential_delay_1000_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_standard_sequential_delay_1000_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_standard_sequential_delay_1000_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_standard_sequential_delay_1000_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_standard_sequential_delay_1000_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_standard_sequential_delay_1000_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_standard_sequential_delay_1000_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_standard_sequential_delay_1000_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_standard_sequential_delay_1000_repetition_10_negation_10.loc[data['update']] = value

# %%
def add_results_to_causal_sequential(value, data):
    if data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_causal_sequential_delay_1_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_causal_sequential_delay_1_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_causal_sequential_delay_1_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_causal_sequential_delay_1_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_causal_sequential_delay_1_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_causal_sequential_delay_1_repetition_5_negation_10.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_causal_sequential_delay_1_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_causal_sequential_delay_1_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_causal_sequential_delay_1_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_causal_sequential_delay_100_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_causal_sequential_delay_100_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_causal_sequential_delay_100_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_causal_sequential_delay_100_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_causal_sequential_delay_100_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_causal_sequential_delay_100_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_causal_sequential_delay_100_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_causal_sequential_delay_100_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_causal_sequential_delay_100_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_causal_sequential_delay_1000_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_causal_sequential_delay_1000_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_causal_sequential_delay_1000_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_causal_sequential_delay_1000_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_causal_sequential_delay_1000_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_causal_sequential_delay_1000_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_causal_sequential_delay_1000_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_causal_sequential_delay_1000_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_causal_sequential_delay_1000_repetition_10_negation_10.loc[data['update']] = value

# %%
def add_results_to_causal_concurrent(value, data):
    if data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_causal_concurrent_delay_1_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_causal_concurrent_delay_1_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_causal_concurrent_delay_1_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_causal_concurrent_delay_1_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_causal_concurrent_delay_1_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_causal_concurrent_delay_1_repetition_5_negation_10.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_causal_concurrent_delay_1_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_causal_concurrent_delay_1_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_causal_concurrent_delay_1_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_causal_concurrent_delay_100_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_causal_concurrent_delay_100_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_causal_concurrent_delay_100_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_causal_concurrent_delay_100_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_causal_concurrent_delay_100_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_causal_concurrent_delay_100_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_causal_concurrent_delay_100_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_causal_concurrent_delay_100_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '100' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_causal_concurrent_delay_100_repetition_10_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '0':
        data_frame_causal_concurrent_delay_1000_repetition_0_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '5':
        data_frame_causal_concurrent_delay_1000_repetition_0_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '0' and data['negation'] == '10':
        data_frame_causal_concurrent_delay_1000_repetition_0_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '0':
        data_frame_causal_concurrent_delay_1000_repetition_5_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '5':
        data_frame_causal_concurrent_delay_1000_repetition_5_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '5' and data['negation'] == '10':
        data_frame_causal_concurrent_delay_1000_repetition_5_negation_10.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '0':
        data_frame_causal_concurrent_delay_1000_repetition_10_negation_0.loc[data['update']] = value
        
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '5':
        data_frame_causal_concurrent_delay_1000_repetition_10_negation_5.loc[data['update']] = value
    
    elif data['delay'] == '1000' and data['repetition'] == '10' and data['negation'] == '10':
        data_frame_causal_concurrent_delay_1000_repetition_10_negation_10.loc[data['update']] = value

# %%
def add_results_to_concurrent(value, data):
    if data['algorithm'] == 'causal':
        add_results_to_causal_concurrent(value, data)
    elif data['algorithm'] == 'standard':
        add_results_to_standard_concurrent(value, data)
    elif data['algorithm'] == 'corrective':
        add_results_to_corrective_concurrent(value, data)
    elif data['algorithm'] == 'preventive':
        add_results_to_preventive_concurrent(value, data)

# %%
def add_results_to_sequential(value, data):
    if data['algorithm'] == 'causal':
        add_results_to_causal_sequential(value, data)
    elif data['algorithm'] == 'standard':
        add_results_to_standard_sequential(value, data)
    elif data['algorithm'] == 'corrective':
        add_results_to_corrective_sequential(value, data)
    elif data['algorithm'] == 'preventive':
        add_results_to_preventive_sequential(value, data)

# %%
def save_all_dataframes_as_pickle():
    print('Called!')
    current_directory = os.getcwd()
    path_results = '/saved_dataframes/'
    algorithm_list = ['causal', 'corrective', 'standard', 'preventive']
    types_list = ['concurrent', 'sequential']
    delay_list = ['1', '100', '1000']
    repetition_probability_list = ['0', '5', '10']
    negation_probability_list = ['0', '5', '10']
    string_name = 'data_frame'
            
    for alg in algorithm_list:
        for ty in types_list:
            for dela in delay_list:
                for rep in repetition_probability_list:
                    for neg in negation_probability_list:
                            var_name = string_name +'_' + alg + '_' + ty +'_delay_' + str(dela) + '_repetition_' + str(rep) + '_negation_' + str(neg)
                            var = globals()[var_name]
                            pickle.dump(var, open(current_directory + path_results + var_name +'.p' , "wb"))

# %%
if recalculate_if_saved:
    new_number = number_of_updates
    for repetition_index in range(0, repetitions):
        file_path = 'local/test/results_experiment_' + str(new_number)
        data = dict()
        data['update'] = number_of_updates * (repetition_index + 1)
        for delay in delay_list:
            data['delay'] = delay
            for repetition_probability in repetition_probability_list:
                data['repetition'] = repetition_probability
                for negation_probability in negation_probability_list:
                    data['negation'] = negation_probability
                    for algorithm in algorithm_list:
                        data['algorithm'] = algorithm
                        for alg_type in types_list:   
                            str_1 = 'result_algorithm_*' + algorithm + '*_type_*' + alg_type + '*_negationProbability_*' + str(negation_probability)
                            str_2 = '*_delay_*' + str(delay) + '.0*_repetitionProbability_*' + str(repetition_probability) + '*.csv'
                            file_name = str_1 + str_2
                            try:
                                result = pd.read_csv(file_path +'/' + file_name, encoding='utf-8', sep=r'\s*,\s*', header=0, engine='python')
                                mean_vector = result.mean(axis=0)
                                if alg_type == 'concurrent':
                                    add_results_to_concurrent(mean_vector, data)
                                elif alg_type == 'sequential':
                                    add_results_to_sequential(mean_vector, data)
                            except FileNotFoundError as e:
                                print(e)

        new_number += number_of_updates
    # print(data_frame_corrective_concurrent_delay_1000_repetition_10_negation_10)
    save_all_dataframes_as_pickle()
# Out:
# [Errno 2] No such file or directory: 'local/test/results_experiment_750/result_algorithm_*corrective*_type_*concurrent*_negationProbability_*10*_delay_*100.0*_repetitionProbability_*5*.csv'
# [Errno 2] No such file or directory: 'local/test/results_experiment_750/result_algorithm_*corrective*_type_*sequential*_negationProbability_*10*_delay_*100.0*_repetitionProbability_*5*.csv'
# Called!

# %% [markdown]
# # Save Dataframes to not calculate again

# %%
# # define the name of the directory to be created
# pickle_paths = '/raw_results'

# path = os.getcwd()
# print ("The current working directory is %s" % path)

# try:
# #     os.mkdir(pickle_paths)
#     os.makedirs(pickle_paths)
# except OSError as e:
#     print ("Creation of the directory %s failed" % pickle_paths)
#     print(e)
# else:
#     print ("Successfully created the directory %s " % pickle_paths)
    


# os.makedirs(os.path.dirname(pickle_paths), exist_ok=True)

# %% [markdown]
# # Plot results

# %%
# ax = data_frame_corrective_concurrent_delay_1000_repetition_10_negation_10['number_of_reconfigurations'].plot()
# ax2 = data_frame_preventive_concurrent_delay_1000_repetition_10_negation_10['number_of_reconfigurations'].plot(ax=ax)
# ax3 = data_frame_causal_concurrent_delay_1000_repetition_10_negation_10['number_of_reconfigurations'].plot(ax=ax2)
# ax4 = data_frame_standard_concurrent_delay_1000_repetition_10_negation_10['number_of_reconfigurations'].plot(ax=ax3, 
#                                                                                                              xlabel="reconfigurations",
#                                                                                                              ylabel="# of reconfigurations",
#                                                                                                             y=['P25th', 'Median', 'P75th','Pa'])
